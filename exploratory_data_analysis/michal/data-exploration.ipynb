# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats

# %% [markdown]
# ## **DATA DESCRIPTION**
# PRODUCT <br/>
#
# AGE - age of the borrower<br/>
#
# AREA - residential area ('County capital' 'Urban area' 'Rural area' 'Missing')<br/>
#
# RESIDENTIAL PLACE - housing situation ('Owner without mortgage' 'Living with family' 'Owner with mortgage'
# 'Rental' 'Other')<br/>
#
# EDUCATION - education level ('University' 'Post-graduate' 'High school' 'Missing'
# 'Post-secondary school' 'Other' 'College' 'Vocational school'
# 'Middle school' 'Primary school')<br/>
#
# MARITAL STATUS - marital status ('married' 'divorced' 'single' 'widow')<br/>
#
# HOUSEHOLD MEMBERS - number of people in the household<br/>
#
# NO OF DEPENDENTS - number of dependents of the client<br/>
#
# INCOME - income ($/month ?)<br/>
#
# WORK SENIORITY - work experience<br/>
#
# BUSINESS AGE - business experience (if self-employed)<br/>
#
# ECONOMIC SECTOR - sector in which the borrower works<br/>
#
# EMPLOYEE NO - number of employees<br/>
#
# LENGTH RELATIONSHIP WITH CLIENT - duration of the business relationship with the client<br/>
#
# DEBIT CARD - whether the client has a debit card<br/>
#
# CURRENT ACCOUNT - <br/>
#
# SAVING ACCOUNT - whether the client has a savings account<br/>
#
# SALARY ACCOUNT - <br/>
#
# FOREIGN ACCOUNT - whether the client has a foreign currency account<br/>
#
# FINALIZED LOAN - whether the client has repaid the loan<br/>
#
# DEPOSIT - <br/>
#
# PENSION FUNDS - <br/>
#
# **DEFAULT FLAG** - whether the client has payment arrears (**1 - yes, 0 - no**)<br/>

# %% [markdown]
# BASIC INFO

# %%
df = pd.read_csv('../../data/orig_train.csv')

# %%
df.head().T
# Out:
#                                                       0  \
# PRODUCT                                               C
# AGE                                                  65
# AREA                                     County capital
# RESIDENTIAL_PLACE                Owner without mortgage
# EDUCATION                                    University
# MARITAL_STATUS                                  married
# HOUSEHOLD_MEMBERS                                     2
# NO_OF_DEPENDENTS                                      0
# INCOME                                           1245.0
# WORK_SENIORITY                                        5
# BUSINESS AGE                                         16
# ECONOMIC_SECTOR                                 Missing
# EMPLOYEE_NO                                     Missing
# LENGTH_RELATIONSHIP_WITH_CLIENT                       1
# DEBIT_CARD                                            0
# CURRENT_ACCOUNT                                       0
# SAVING_ACCOUNT                                        0
# SALARY_ACCOUNT                                        0
# FOREIGN_ACCOUNT                                       0
# FINALIZED_LOAN                                        0
# DEPOSIT                                               0
# PENSION_FUNDS                                         0
# DEFAULT_FLAG                                          0
#
#                                                       1                   2  \
# PRODUCT                                               C                   F
# AGE                                                  64                  30
# AREA                                     County capital          Urban area
# RESIDENTIAL_PLACE                Owner without mortgage  Living with family
# EDUCATION                                    University          University
# MARITAL_STATUS                                  married             married
# HOUSEHOLD_MEMBERS                                     2                   2
# NO_OF_DEPENDENTS                                      0                   0
# INCOME                                           1380.0              1131.0
# WORK_SENIORITY                                        5                   2
# BUSINESS AGE                                         16                   6
# ECONOMIC_SECTOR                                 Missing               Other
# EMPLOYEE_NO                                     Missing             > 1.000
# LENGTH_RELATIONSHIP_WITH_CLIENT                       8                   1
# DEBIT_CARD                                            0                   1
# CURRENT_ACCOUNT                                       0                   1
# SAVING_ACCOUNT                                        0                   0
# SALARY_ACCOUNT                                        0                   0
# FOREIGN_ACCOUNT                                       0                   0
# FINALIZED_LOAN                                        0                   0
# DEPOSIT                                               0                   0
# PENSION_FUNDS                                         0                   0
# DEFAULT_FLAG                                          0                   0
#
#                                                       3  \
# PRODUCT                                               C
# AGE                                                  39
# AREA                                     County capital
# RESIDENTIAL_PLACE                Owner without mortgage
# EDUCATION                                 Post-graduate
# MARITAL_STATUS                                 divorced
# HOUSEHOLD_MEMBERS                                     1
# NO_OF_DEPENDENTS                                      0
# INCOME                                           1730.0
# WORK_SENIORITY                                        9
# BUSINESS AGE                                         13
# ECONOMIC_SECTOR                               Education
# EMPLOYEE_NO                               between 11-20
# LENGTH_RELATIONSHIP_WITH_CLIENT                       2
# DEBIT_CARD                                            0
# CURRENT_ACCOUNT                                       0
# SAVING_ACCOUNT                                        0
# SALARY_ACCOUNT                                        0
# FOREIGN_ACCOUNT                                       0
# FINALIZED_LOAN                                        0
# DEPOSIT                                               0
# PENSION_FUNDS                                         0
# DEFAULT_FLAG                                          0
#
#                                                       4
# PRODUCT                                               B
# AGE                                                  38
# AREA                                     County capital
# RESIDENTIAL_PLACE                Owner without mortgage
# EDUCATION                                    Highschool
# MARITAL_STATUS                                   single
# HOUSEHOLD_MEMBERS                                     1
# NO_OF_DEPENDENTS                                      0
# INCOME                                           1189.0
# WORK_SENIORITY                                        5
# BUSINESS AGE                                         16
# ECONOMIC_SECTOR                                 Missing
# EMPLOYEE_NO                                     Missing
# LENGTH_RELATIONSHIP_WITH_CLIENT                       1
# DEBIT_CARD                                            1
# CURRENT_ACCOUNT                                       1
# SAVING_ACCOUNT                                        0
# SALARY_ACCOUNT                                        0
# FOREIGN_ACCOUNT                                       0
# FINALIZED_LOAN                                        0
# DEPOSIT                                               0
# PENSION_FUNDS                                         0
# DEFAULT_FLAG                                          0

# %%
df.rename(columns={'BUSINESS AGE': 'BUSINESS_AGE'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15097 entries, 0 to 15096
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   PRODUCT                          15097 non-null  object
#  1   AGE                              15097 non-null  int64
#  2   AREA                             15097 non-null  object
#  3   RESIDENTIAL_PLACE                15097 non-null  object
#  4   EDUCATION                        15097 non-null  object
#  5   MARITAL_STATUS                   15097 non-null  object
#  6   HOUSEHOLD_MEMBERS                15097 non-null  int64
#  7   NO_OF_DEPENDENTS                 15097 non-null  int64
#  8   INCOME                           15097 non-null  float64
#  9   WORK_SENIORITY                   15097 non-null  int64
#  10  BUSINESS_AGE                     15097 non-null  int64
#  11  ECONOMIC_SECTOR                  15097 non-null  object
#  12  EMPLOYEE_NO                      15097 non-null  object
#  13  LENGTH_RELATIONSHIP_WITH_CLIENT  15097 non-null  int64
#  14  DEBIT_CARD                       15097 non-null  int64
#  15  CURRENT_ACCOUNT                  15097 non-null  int64
#  16  SAVING_ACCOUNT                   15097 non-null  int64
#  17  SALARY_ACCOUNT                   15097 non-null  int64
#  18  FOREIGN_ACCOUNT                  15097 non-null  int64
#  19  FINALIZED_LOAN                   15097 non-null  int64
#  20  DEPOSIT                          15097 non-null  int64
#  21  PENSION_FUNDS                    15097 non-null  int64
#  22  DEFAULT_FLAG                     15097 non-null  int64
# dtypes: float64(1), int64(15), object(7)
# memory usage: 2.6+ MB

# %% [markdown]
# No null values in data frame

# %%
for col in df:
    print(col, df[col].unique())
# Out:
# PRODUCT ['C' 'F' 'B' 'E' 'D' 'A']
# AGE [65 64 30 39 38 40 45 27 34 28 41 42 63 32 47 67 68 33 44 24 54 57 46 37
#  31 35 25 36 66 51 50 29 23 59 61 62 22 48 43 53 55 21 26 56 60 49 52 58
#  19 69 70 20 74]
# AREA ['County capital' 'Urban area' 'Rural area' 'Missing']
# RESIDENTIAL_PLACE ['Owner without mortgage' 'Living with family' 'Owner with mortgage'
#  'Rental' 'Other']
# EDUCATION ['University' 'Post-graduate' 'Highschool' 'Missing'
#  'Post secondary school' 'Other' 'College' 'Vocational school'
#  'Middle school' 'Primary school']
# MARITAL_STATUS ['married' 'divorced' 'single' 'widow']
# HOUSEHOLD_MEMBERS [2 1 3 4 5]
# NO_OF_DEPENDENTS [0 1 2 3 4]
# INCOME [1245.   1380.   1131.   ... 5112.   2015.17 3733.6 ]
# WORK_SENIORITY [ 5  2  9  7  4 20  3 10  8  1 13 32  6 12 17 28 16 18 14 11 15 38 19 36
#  21 22 25 24 45 23 37 27 26 43 29 40 35 33 30 31 34 39 41 46 42]
# BUSINESS AGE [ 16   6  13   9  12  18  23  15  11  17  22  14  24  33  25  19   5  10
#    8   3  32  51  21  35  20  26  52  42  86  43   4  46  62  36  66  61
#    2  38 106  54  41   7  92  47  45   1  50  55  68  40  44  34  37  39
#   57  97  27  59  60  56 115  67  30 107  74  49  28  81  95  96 105  69
#   29 111  76  98  80  64  65 112 116  72 103  63  48  75  85  53  91  31
#   83  93  70 102  94  87 104  58  78  71 114  99  79 109  88  73  82  84]
# ECONOMIC_SECTOR ['Missing' 'Other' 'Education' 'Manufacturing'
#  'Public administration and defence' 'Wholesale and retail trade'
#  'Human health and social work activities'
#  'Professional, scientific and technical activities' 'Electricity and gas'
#  'Transportation and storage' 'Construction' 'Water supply'
#  'Mining and quarrying' 'Information and communication'
#  'Agriculture, hunting and forestry' 'Financial and insurance activities'
#  'Accommodation and food service activities' 'Real estate activities']
# EMPLOYEE_NO ['Missing' '> 1.000' 'between 11-20' 'between 101-250' 'between 0-10'
#  'between 51-100' 'between 21-50' 'between 501-1.000' 'between 251-500']
# LENGTH_RELATIONSHIP_WITH_CLIENT [  1   8   2  12  13   9  10   7   3  11  15  14   6   4   5  17  16  18
#   20  19 110  22  21]
# DEBIT_CARD [0 1]
# CURRENT_ACCOUNT [0 1]
# SAVING_ACCOUNT [0 1]
# SALARY_ACCOUNT [0 1]
# FOREIGN_ACCOUNT [0 1]
# FINALIZED_LOAN [0 1]
# DEPOSIT [0 1]
# PENSION_FUNDS [0]
# DEFAULT_FLAG [0 1]

# %%
df.hist(bins = 40, figsize = (18, 10))
plt.show()

# %%
categorical_variables = df.select_dtypes(include=['object'])

def plot_categorical_distribution(df):
    num_columns = len(df.columns)
    num_rows = (num_columns + 1) // 2

    fig, axes = plt.subplots(num_rows, 2, figsize=(15, 5*num_rows))
    axes = axes.flatten()

    for i, column in enumerate(df.columns):
        sns.countplot(data=df, y=column, order=df[column].value_counts().index, ax=axes[i])
        axes[i].set_title(f'Distribution of {column}')
        axes[i].set_xlabel(column)
        axes[i].set_ylabel('Count')
        axes[i].tick_params(axis='x', rotation=45) 
    
    axes[-1].axis('off')

    plt.tight_layout()
    plt.show()

plot_categorical_distribution(categorical_variables)

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (18, 10))
sns.countplot(x = "RESIDENTIAL_PLACE", hue = "DEFAULT_FLAG", data = df, ax = axes[0, 0])
sns.countplot(x = "EDUCATION", hue = "DEFAULT_FLAG", data = df, ax = axes[0, 1])
sns.countplot(x = "AREA", hue = "DEFAULT_FLAG", data = df, ax = axes[1, 0])
sns.countplot(x = "MARITAL_STATUS", hue = "DEFAULT_FLAG", data = df, ax = axes[1, 1])
sns.countplot(x = "EMPLOYEE_NO", hue = "DEFAULT_FLAG", data = df, ax = axes[2, 0])
sns.countplot(x = "PRODUCT", hue = "DEFAULT_FLAG", data = df, ax = axes[2, 1])

axes[0, 0].tick_params(axis = "x", labelsize = 7)
axes[0, 1].tick_params(axis = "x", labelsize = 7)
axes[2, 0].tick_params(axis = "x", labelsize = 5)

# %% [markdown]
# ## Comments
#
# Columns 'economic_sector' and 'employee_no' have a lot of Missing values
#
# Small portion of products are of type A or D
#
# Something more?

# %%
col_names = ['AREA', 'EDUCATION', 'ECONOMIC_SECTOR', 'EMPLOYEE_NO']
for col_name in col_names:
    print(df[col_name].value_counts()['Missing']/len(df))
# Out:
# 0.002185864741339339
# 0.04577068291713585
# 0.2655494469099821
# 0.2211035305027489

# %% [markdown]
# ## How is income related to education

# %%
plt.figure(figsize=(12, 10))
sns.violinplot(data=df, y='EDUCATION', x='INCOME')
plt.xlim(0, 10000)
plt.show()

# %% [markdown]
# Postgraduates and university graduates have higher income compared to other groups

# %% [markdown]
# ## Household members relation to marital status

# %%
sns.countplot(data=df, y='MARITAL_STATUS', hue='HOUSEHOLD_MEMBERS')
plt.show()

# %% [markdown]
# Jakos madrze napisac, ze wiadomo ze w malzenstwie raczej co najmniej 2 osoby beda a w pozostalych grupach dominuje 1

# %%
columns_to_plot = ['AGE', 'INCOME', 'WORK_SENIORITY', 'BUSINESS_AGE', 'LENGTH_RELATIONSHIP_WITH_CLIENT']

pair_grid = sns.pairplot(df[columns_to_plot], kind="scatter")

for i, j in zip(*np.triu_indices_from(pair_grid.axes, 1)):
    pair_grid.axes[i, j].set_visible(False)

plt.show()

# %% [markdown]
# WORK_SENIORITY > AGE ?? also some anomaly in variable LENGTH_RELATIONSHIP_WITH_CLIENT

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# ### LENGTH_RELATIONSHIP_WITH_CLIENT

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (18, 8))

sns.violinplot(x = df["LENGTH_RELATIONSHIP_WITH_CLIENT"], ax = axes[0, 0])
sns.boxplot(x = df["LENGTH_RELATIONSHIP_WITH_CLIENT"], ax = axes[0, 1])
sns.histplot(x = df["LENGTH_RELATIONSHIP_WITH_CLIENT"], ax = axes[1, 0], kde = True, stat = "density", linewidth = 0)
sns.histplot(x = np.log1p(df["LENGTH_RELATIONSHIP_WITH_CLIENT"]), ax = axes[1, 1], kde=True, stat = "density", linewidth = 0)

fig.suptitle("LENGTH_RELATIONSHIP_WITH_CLIENT - DISTRIBUTION", size = 20)
axes[1, 0].set_xlabel("LENGTH_RELATIONSHIP_WITH_CLIENT")
axes[1, 1].set_xlabel("log(LENGTH_RELATIONSHIP_WITH_CLIENT)")

plt.show()

# %%
z = np.abs(stats.zscore(df["LENGTH_RELATIONSHIP_WITH_CLIENT"]))
outliers = df[z > 3]
print("number of outliers: " + str(len(outliers)))
print("% of outliers: " +  str(round(len(outliers) * 100 / len(df), 3)) + " %")
# Out:
# number of outliers: 22
# % of outliers: 0.146 %

# %% [markdown]
# ### WORK_SENIORITY

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (18, 8))

sns.violinplot(x = df["WORK_SENIORITY"], ax = axes[0, 0])
sns.boxplot(x = df["WORK_SENIORITY"], ax = axes[0, 1])
sns.histplot(x = df["WORK_SENIORITY"], ax = axes[1, 0], kde = True, stat = "density", linewidth = 0)
sns.histplot(x = np.log1p(df["WORK_SENIORITY"]), ax = axes[1, 1], kde = True, stat = "density", linewidth = 0)

fig.suptitle("WORK_SENIORITY - DISTRIBUTION", size = 20)
axes[1, 0].set_xlabel("WORK_SENIORITY")
axes[1, 1].set_xlabel("log(WORK_SENIORITY)")

plt.show()

# %%
z = np.abs(stats.zscore(df["WORK_SENIORITY"]))
outliers = df[z > 3]
print("number of outliers: " + str(len(outliers)))
print("% of outliers: " +  str(round(len(outliers) * 100 / len(df), 3)) + " %")
# Out:
# number of outliers: 403
# % of outliers: 2.669 %

# %% [markdown]
# ### BUSINESS AGE

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (18, 8))

sns.violinplot(x = df["BUSINESS_AGE"], ax = axes[0, 0])
sns.boxplot(x = df["BUSINESS_AGE"], ax = axes[0, 1])
sns.histplot(x = df["BUSINESS_AGE"], ax = axes[1, 0], kde = True, stat = "density", linewidth = 0)
sns.histplot(x = np.log1p(df["BUSINESS_AGE"]), ax = axes[1, 1], kde=True, stat = "density", linewidth = 0)

fig.suptitle("BUSINESS AGE - DISTRIBUTION", size = 20)
axes[1, 0].set_xlabel("BUSINESS_AGE")
axes[1, 1].set_xlabel("log(BUSINESS_AGE)")

plt.show()

# %%
z = np.abs(stats.zscore(df["BUSINESS_AGE"]))
outliers = df[z > 3]
print("number of outliers: " + str(len(outliers)))
print("% of outliers: " +  str(round(len(outliers) * 100 / len(df), 3)) + " %")
# Out:
# number of outliers: 363
# % of outliers: 2.404 %

# %% [markdown]
# ### **OUTLIERS - CONCLUSION**
# - maxiumum values of LENGTH_RELATIONSHIP_WITH_CLIENT **are** outliers
# - maxiumum values of WORK_SENIORITY **are NOT** outliers
# - maxiumum values of BUSINESS AGE **are NOT** outliers

# %% [markdown]
# # IMPUTATION

# %% [markdown]
# Imputing missing values, first we check the most frequent value in each column

# %%
for col_name in col_names:
    most_frequent = df[col_name].mode()
    print(most_frequent)
# Out:
# 0    County capital
# Name: AREA, dtype: object
# 0    University
# Name: EDUCATION, dtype: object
# 0    Missing
# Name: ECONOMIC_SECTOR, dtype: object
# 0    Missing
# Name: EMPLOYEE_NO, dtype: object

# %% [markdown]
# In two columns mode is the missing value, we have to imput it using different technique
# In the two remaining columns we replace missing values with mode

# %%
df['AREA'] = df['AREA'].replace('Missing', df['AREA'].mode()[0])
df['EDUCATION'] = df['EDUCATION'].replace('Missing', df['EDUCATION'].mode()[0])

# %% [markdown]
# In the remaining columns we will impute misisng values so that they matching non-missing values distribution

# %%
def impute_following_distribution(df, col_name):
    value_counts = df[col_name].value_counts()
    number_of_missing_values = value_counts['Missing']
    value_counts_dict = value_counts[1:].to_dict()

    for key in value_counts_dict.keys():
        value_counts_dict[key] = value_counts_dict[key] / (len(df) - number_of_missing_values)

    df[col_name] = df[col_name].replace('Missing', np.random.choice(list(value_counts_dict.keys()), p=list(value_counts_dict.values())))

impute_following_distribution(df, 'ECONOMIC_SECTOR')
impute_following_distribution(df, 'EMPLOYEE_NO')

for col in df:
    print(col, df[col].unique())
# Out:
# PRODUCT ['C' 'F' 'B' 'E' 'D' 'A']
# AGE [65 64 30 39 38 40 45 27 34 28 41 42 63 32 47 67 68 33 44 24 54 57 46 37
#  31 35 25 36 66 51 50 29 23 59 61 62 22 48 43 53 55 21 26 56 60 49 52 58
#  19 69 70 20 74]
# AREA ['County capital' 'Urban area' 'Rural area']
# RESIDENTIAL_PLACE ['Owner without mortgage' 'Living with family' 'Owner with mortgage'
#  'Rental' 'Other']
# EDUCATION ['University' 'Post-graduate' 'Highschool' 'Post secondary school' 'Other'
#  'College' 'Vocational school' 'Middle school' 'Primary school']
# MARITAL_STATUS ['married' 'divorced' 'single' 'widow']
# HOUSEHOLD_MEMBERS [2 1 3 4 5]
# NO_OF_DEPENDENTS [0 1 2 3 4]
# INCOME [1245.   1380.   1131.   ... 5112.   2015.17 3733.6 ]
# WORK_SENIORITY [ 5  2  9  7  4 20  3 10  8  1 13 32  6 12 17 28 16 18 14 11 15 38 19 36
#  21 22 25 24 45 23 37 27 26 43 29 40 35 33 30 31 34 39 41 46 42]
# BUSINESS AGE [ 16   6  13   9  12  18  23  15  11  17  22  14  24  33  25  19   5  10
#    8   3  32  51  21  35  20  26  52  42  86  43   4  46  62  36  66  61
#    2  38 106  54  41   7  92  47  45   1  50  55  68  40  44  34  37  39
#   57  97  27  59  60  56 115  67  30 107  74  49  28  81  95  96 105  69
#   29 111  76  98  80  64  65 112 116  72 103  63  48  75  85  53  91  31
#   83  93  70 102  94  87 104  58  78  71 114  99  79 109  88  73  82  84]
# ECONOMIC_SECTOR ['Construction' 'Other' 'Education' 'Manufacturing'
#  'Public administration and defence' 'Wholesale and retail trade'
#  'Human health and social work activities'
#  'Professional, scientific and technical activities' 'Electricity and gas'
#  'Transportation and storage' 'Water supply' 'Mining and quarrying'
#  'Information and communication' 'Agriculture, hunting and forestry'
#  'Financial and insurance activities'
#  'Accommodation and food service activities' 'Real estate activities']
# EMPLOYEE_NO ['between 501-1.000' '> 1.000' 'between 11-20' 'between 101-250'
#  'between 0-10' 'between 51-100' 'between 21-50' 'between 251-500']
# LENGTH_RELATIONSHIP_WITH_CLIENT [  1   8   2  12  13   9  10   7   3  11  15  14   6   4   5  17  16  18
#   20  19 110  22  21]
# DEBIT_CARD [0 1]
# CURRENT_ACCOUNT [0 1]
# SAVING_ACCOUNT [0 1]
# SALARY_ACCOUNT [0 1]
# FOREIGN_ACCOUNT [0 1]
# FINALIZED_LOAN [0 1]
# DEPOSIT [0 1]
# PENSION_FUNDS [0]
# DEFAULT_FLAG [0 1]

# %%
df.describe().T
# Out:
#                                    count         mean          std   min  \
# AGE                              15097.0    43.584553    13.460964  19.0
# HOUSEHOLD_MEMBERS                15097.0     1.717229     0.759843   1.0
# NO_OF_DEPENDENTS                 15097.0     0.199510     0.493135   0.0
# INCOME                           15097.0  1958.071916  1772.153274   0.0
# WORK_SENIORITY                   15097.0     6.647347     5.647763   1.0
# BUSINESS AGE                     15097.0    17.938001    12.477914   1.0
# LENGTH_RELATIONSHIP_WITH_CLIENT  15097.0     4.996556     4.900952   1.0
# DEBIT_CARD                       15097.0     0.384116     0.486402   0.0
# CURRENT_ACCOUNT                  15097.0     0.485461     0.499805   0.0
# SAVING_ACCOUNT                   15097.0     0.000397     0.019932   0.0
# SALARY_ACCOUNT                   15097.0     0.123203     0.328681   0.0
# FOREIGN_ACCOUNT                  15097.0     0.000132     0.011509   0.0
# FINALIZED_LOAN                   15097.0     0.164205     0.370474   0.0
# DEPOSIT                          15097.0     0.003709     0.060793   0.0
# PENSION_FUNDS                    15097.0     0.000000     0.000000   0.0
# DEFAULT_FLAG                     15097.0     0.057230     0.232289   0.0
#
#                                      25%       50%     75%      max
# AGE                                32.00    42.000    56.0     74.0
# HOUSEHOLD_MEMBERS                   1.00     2.000     2.0      5.0
# NO_OF_DEPENDENTS                    0.00     0.000     0.0      4.0
# INCOME                           1007.42  1426.495  2290.0  40621.6
# WORK_SENIORITY                      3.00     5.000     8.0     46.0
# BUSINESS AGE                       12.00    16.000    21.0    116.0
# LENGTH_RELATIONSHIP_WITH_CLIENT     1.00     2.000    10.0    110.0
# DEBIT_CARD                          0.00     0.000     1.0      1.0
# CURRENT_ACCOUNT                     0.00     0.000     1.0      1.0
# SAVING_ACCOUNT                      0.00     0.000     0.0      1.0
# SALARY_ACCOUNT                      0.00     0.000     0.0      1.0
# FOREIGN_ACCOUNT                     0.00     0.000     0.0      1.0
# FINALIZED_LOAN                      0.00     0.000     0.0      1.0
# DEPOSIT                             0.00     0.000     0.0      1.0
# PENSION_FUNDS                       0.00     0.000     0.0      0.0
# DEFAULT_FLAG                        0.00     0.000     0.0      1.0

# %% [markdown]
# Some variables seem to have low variance: saving_account, foreign_account, deposit, pension_funds

# %%
low_variance_col_names = ['SAVING_ACCOUNT', 'FOREIGN_ACCOUNT', 'DEPOSIT', 'PENSION_FUNDS']
for col_name in low_variance_col_names:
    print(df[col_name].value_counts())
# Out:
# SAVING_ACCOUNT
# 0    15091
# 1        6
# Name: count, dtype: int64
# FOREIGN_ACCOUNT
# 0    15095
# 1        2
# Name: count, dtype: int64
# DEPOSIT
# 0    15041
# 1       56
# Name: count, dtype: int64
# PENSION_FUNDS
# 0    15097
# Name: count, dtype: int64

# %% [markdown]
# We can delete above variables from dataframe

# %%
df = df.drop(low_variance_col_names, axis=1)

# %% [markdown]
# Encoding categorical variables
#
# Variables that are not ordinal: Product, Area, Residential_place, Education, Martial_status
#
# We will encode Employee_no to preserve order of its values

# %%
categorical_col_names = ['PRODUCT', 'AREA', 'RESIDENTIAL_PLACE', 'EDUCATION', 'MARITAL_STATUS',
       'ECONOMIC_SECTOR']

df = pd.get_dummies(df, columns=categorical_col_names)

# %%
df.EMPLOYEE_NO.unique()
# Out:
# array(['between 501-1.000', '> 1.000', 'between 11-20', 'between 101-250',
#        'between 0-10', 'between 51-100', 'between 21-50',
#        'between 251-500'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinalEncoder = OrdinalEncoder(categories=[['between 0-10', 'between 11-20',
                                             'between 21-50', 'between 51-100',
                                             'between 101-250', 'between 251-500',
                                             'between 501-1.000', '> 1.000']])

df['EMPLOYEE_NO'] = ordinalEncoder.fit_transform(df[['EMPLOYEE_NO']])

# %%
df.head().T
# Out:
#                                                          0       1       2  \
# AGE                                                     65      64      30
# HOUSEHOLD_MEMBERS                                        2       2       2
# NO_OF_DEPENDENTS                                         0       0       0
# INCOME                                              1245.0  1380.0  1131.0
# WORK_SENIORITY                                           5       5       2
# BUSINESS AGE                                            16      16       6
# EMPLOYEE_NO                                            6.0     6.0     7.0
# LENGTH_RELATIONSHIP_WITH_CLIENT                          1       8       1
# DEBIT_CARD                                               0       0       1
# CURRENT_ACCOUNT                                          0       0       1
# SALARY_ACCOUNT                                           0       0       0
# FINALIZED_LOAN                                           0       0       0
# DEFAULT_FLAG                                             0       0       0
# PRODUCT_A                                            False   False   False
# PRODUCT_B                                            False   False   False
# PRODUCT_C                                             True    True   False
# PRODUCT_D                                            False   False   False
# PRODUCT_E                                            False   False   False
# PRODUCT_F                                            False   False    True
# AREA_County capital                                   True    True   False
# AREA_Rural area                                      False   False   False
# AREA_Urban area                                      False   False    True
# RESIDENTIAL_PLACE_Living with family                 False   False    True
# RESIDENTIAL_PLACE_Other                              False   False   False
# RESIDENTIAL_PLACE_Owner with mortgage                False   False   False
# RESIDENTIAL_PLACE_Owner without mortgage              True    True   False
# RESIDENTIAL_PLACE_Rental                             False   False   False
# EDUCATION_College                                    False   False   False
# EDUCATION_Highschool                                 False   False   False
# EDUCATION_Middle school                              False   False   False
# EDUCATION_Other                                      False   False   False
# EDUCATION_Post secondary school                      False   False   False
# EDUCATION_Post-graduate                              False   False   False
# EDUCATION_Primary school                             False   False   False
# EDUCATION_University                                  True    True    True
# EDUCATION_Vocational school                          False   False   False
# MARITAL_STATUS_divorced                              False   False   False
# MARITAL_STATUS_married                                True    True    True
# MARITAL_STATUS_single                                False   False   False
# MARITAL_STATUS_widow                                 False   False   False
# ECONOMIC_SECTOR_Accommodation and food service ...   False   False   False
# ECONOMIC_SECTOR_Agriculture, hunting and forestry    False   False   False
# ECONOMIC_SECTOR_Construction                          True    True   False
# ECONOMIC_SECTOR_Education                            False   False   False
# ECONOMIC_SECTOR_Electricity and gas                  False   False   False
# ECONOMIC_SECTOR_Financial and insurance activities   False   False   False
# ECONOMIC_SECTOR_Human health and social work ac...   False   False   False
# ECONOMIC_SECTOR_Information and communication        False   False   False
# ECONOMIC_SECTOR_Manufacturing                        False   False   False
# ECONOMIC_SECTOR_Mining and quarrying                 False   False   False
# ECONOMIC_SECTOR_Other                                False   False    True
# ECONOMIC_SECTOR_Professional, scientific and te...   False   False   False
# ECONOMIC_SECTOR_Public administration and defence    False   False   False
# ECONOMIC_SECTOR_Real estate activities               False   False   False
# ECONOMIC_SECTOR_Transportation and storage           False   False   False
# ECONOMIC_SECTOR_Water supply                         False   False   False
# ECONOMIC_SECTOR_Wholesale and retail trade           False   False   False
#
#                                                          3       4
# AGE                                                     39      38
# HOUSEHOLD_MEMBERS                                        1       1
# NO_OF_DEPENDENTS                                         0       0
# INCOME                                              1730.0  1189.0
# WORK_SENIORITY                                           9       5
# BUSINESS AGE                                            13      16
# EMPLOYEE_NO                                            1.0     6.0
# LENGTH_RELATIONSHIP_WITH_CLIENT                          2       1
# DEBIT_CARD                                               0       1
# CURRENT_ACCOUNT                                          0       1
# SALARY_ACCOUNT                                           0       0
# FINALIZED_LOAN                                           0       0
# DEFAULT_FLAG                                             0       0
# PRODUCT_A                                            False   False
# PRODUCT_B                                            False    True
# PRODUCT_C                                             True   False
# PRODUCT_D                                            False   False
# PRODUCT_E                                            False   False
# PRODUCT_F                                            False   False
# AREA_County capital                                   True    True
# AREA_Rural area                                      False   False
# AREA_Urban area                                      False   False
# RESIDENTIAL_PLACE_Living with family                 False   False
# RESIDENTIAL_PLACE_Other                              False   False
# RESIDENTIAL_PLACE_Owner with mortgage                False   False
# RESIDENTIAL_PLACE_Owner without mortgage              True    True
# RESIDENTIAL_PLACE_Rental                             False   False
# EDUCATION_College                                    False   False
# EDUCATION_Highschool                                 False    True
# EDUCATION_Middle school                              False   False
# EDUCATION_Other                                      False   False
# EDUCATION_Post secondary school                      False   False
# EDUCATION_Post-graduate                               True   False
# EDUCATION_Primary school                             False   False
# EDUCATION_University                                 False   False
# EDUCATION_Vocational school                          False   False
# MARITAL_STATUS_divorced                               True   False
# MARITAL_STATUS_married                               False   False
# MARITAL_STATUS_single                                False    True
# MARITAL_STATUS_widow                                 False   False
# ECONOMIC_SECTOR_Accommodation and food service ...   False   False
# ECONOMIC_SECTOR_Agriculture, hunting and forestry    False   False
# ECONOMIC_SECTOR_Construction                         False    True
# ECONOMIC_SECTOR_Education                             True   False
# ECONOMIC_SECTOR_Electricity and gas                  False   False
# ECONOMIC_SECTOR_Financial and insurance activities   False   False
# ECONOMIC_SECTOR_Human health and social work ac...   False   False
# ECONOMIC_SECTOR_Information and communication        False   False
# ECONOMIC_SECTOR_Manufacturing                        False   False
# ECONOMIC_SECTOR_Mining and quarrying                 False   False
# ECONOMIC_SECTOR_Other                                False   False
# ECONOMIC_SECTOR_Professional, scientific and te...   False   False
# ECONOMIC_SECTOR_Public administration and defence    False   False
# ECONOMIC_SECTOR_Real estate activities               False   False
# ECONOMIC_SECTOR_Transportation and storage           False   False
# ECONOMIC_SECTOR_Water supply                         False   False
# ECONOMIC_SECTOR_Wholesale and retail trade           False   False

# %%
#to musze zrobic ladniejsze

sns.heatmap(df.corr(), cmap = 'coolwarm', fmt='.1f', center = 0, vmin = -1, vmax = 1)
# Out:
# <Axes: >
