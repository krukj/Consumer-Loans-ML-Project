# %% [markdown]
# ## Pipeline for processing data

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
import warnings
warnings.filterwarnings('ignore')

X_train = pd.read_csv('../data/orig_train.csv')
target = X_train['DEFAULT_FLAG']
X_train.drop(columns=['DEFAULT_FLAG'], inplace=True)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler, MinMaxScaler


# Simple column remover to remove low variance columns
class FeatureRemover(BaseEstimator, TransformerMixin):
    def __init__(self, columns_to_drop):
        self.columns_to_drop = columns_to_drop
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return X.drop(self.columns_to_drop,axis=1)

# Update name of the column
class FeatureNameUpdater(BaseEstimator, TransformerMixin):
    def __init__(self, old_name, new_name):
        self.old_name = old_name
        self.new_name = new_name
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X.rename(columns = {self.old_name: self.new_name}, inplace = True)
        
        return X
    
# Imputes missing values with mode and according to distribution of columns
class MyImputer(BaseEstimator, TransformerMixin):
    def __init__(self, cols_mode_imputation, cols_dist_imputation):
        self.modes = {}
        self.distributions_of_columns = {}
        self.cols_mode_imputation = cols_mode_imputation
        self.cols_dist_imputation = cols_dist_imputation
    
    # Function to create dictionary containing distribution of a categorical column
    def get_col_distribution(self, X, col_name):
        value_counts = X[col_name].value_counts()
        number_of_missing_values = value_counts["Missing"]
        value_counts_dict = value_counts[1:].to_dict()
        
        # change to probabilities
        for key in value_counts_dict:
            value_counts_dict[key] = value_counts_dict[key] / (len(X) - number_of_missing_values)

        # if probabilites do not sum to 1 due to numerical errors
        if 0.99 < sum(value_counts_dict.values()) < 1:
            max_value = max(value_counts_dict.values())
            max_key = [key for key, value in value_counts_dict.items() if value == max_value][0]

            value_counts_dict[max_key] += 1 - sum(value_counts_dict.values())

        return value_counts_dict

    def fit(self, X, y=None):
        for col_name in self.cols_mode_imputation:
            self.modes[col_name] = X[col_name].mode()[0]
        
        for col_name in self.cols_dist_imputation:
            self.distributions_of_columns[col_name] = self.get_col_distribution(X, col_name)
        
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        
        for col_name in self.cols_mode_imputation:
            X_copy[col_name] = X[col_name].replace('Missing', self.modes[col_name])
        
        for col_name in self.cols_dist_imputation:
            column_distribution = self.distributions_of_columns[col_name]
            
            X_copy[col_name] = X[col_name].replace('Missing',
                                              np.random.choice(list(column_distribution.keys()), 
                                                        p = list(column_distribution.values())))
        
        return X_copy

# Encoder for categorical variables handling both ordered and unordered ones
class MyEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, cat_features_wo_order, cat_feature_with_order, categories_order):
        self.cat_features_wo_order = cat_features_wo_order
        self.cat_feature_with_order = cat_feature_with_order
        self.categories_order = categories_order
        self.ordinal_encoder = OrdinalEncoder(categories=[categories_order])

    def fit(self, X, y=None):
        self.ordinal_encoder.fit(X[[self.cat_feature_with_order]])

        return self

    def transform(self, X, y=None):
        X_copy = pd.get_dummies(X, columns=self.cat_features_wo_order)

        X_copy[self.cat_feature_with_order] = self.ordinal_encoder.transform(X[[self.cat_feature_with_order]])

        return X_copy

# scaling the data, based on choice it will either standarize(default) or normalize,
class MyScaler(BaseEstimator, TransformerMixin):
    def __init__(self, standarize=True):
        self.standarize = standarize
        
        if self.standarize is True:
            self.scaler = StandardScaler()
        else:
            self.scaler = MinMaxScaler()

    def fit(self, X, y=None):
        # we want to scale only numerical columns
        X_num_cols = X.select_dtypes(include=['float64', 'int64'])
        
        self.scaler.fit(X_num_cols)
        
        return self

    def transform(self, X, y=None):
        X_num_cols = X.select_dtypes(include=['float64', 'int64'])
        
        # transform numerical columns
        X_num_cols_transformed = self.scaler.transform(X_num_cols)
        
        # change to df to access columns
        X_num_cols_transformed_df = pd.DataFrame(X_num_cols_transformed, columns=X_num_cols.columns, index=X_num_cols.index)

        # change them in X
        X_copy = X.copy()
        for col_name in X_num_cols_transformed_df.columns:
            X_copy[col_name] = X_num_cols_transformed_df[col_name]

        return X_copy
    

class OutlierReplacer(BaseEstimator, TransformerMixin):
    # It will replace outliers from columns based on provided dictionary(for now list of columns)
    # If to_remove_dict[col_name] is true outliers will be removed (and exchanged with a proper quantile)
    # It is possible to adjust parameter k, by default its set to 1.5 as usually it is done
    def __init__(self, columns=None, k=1.5):
        self.columns = columns
        self.k = k
        self.lower_bounds = {}
        self.upper_bounds = {}
        
    def fit(self, X, y=None):
        # Compute lower and upper bounds for each specified column
        if self.columns is None:
            self.columns = X.columns
        for col in self.columns:
            q1 = X[col].quantile(0.25)
            q3 = X[col].quantile(0.75)
            iqr = q3 - q1
            lower_bound = q1 - self.k * iqr
            upper_bound = q3 + self.k * iqr
            self.lower_bounds[col] = lower_bound
            self.upper_bounds[col] = upper_bound
        return self
    
    def transform(self, X, y=None):
        # Replace outliers in specified columns with calculated bounds
        X_copy = X.copy()
        for col in self.columns:
            lower_bound = self.lower_bounds[col]
            upper_bound = self.upper_bounds[col]
            X_copy[col] = X_copy[col].clip(lower_bound, upper_bound)
        return X_copy

# %%
from sklearn.pipeline import Pipeline

pipeline_processing = Pipeline([
    # first we remove low variance columns (chosen during EDA) and FINALIZED_LOAN as variable from future
    ('feature_remover', FeatureRemover(['SAVING_ACCOUNT', 'FOREIGN_ACCOUNT', 'DEPOSIT', 'PENSION_FUNDS', 'FINALIZED_LOAN'])), # first 4 columns are removed because of low variance, FINALIZED_LOAN removed as a feature from future
   
    # then we update the name of column BUSINESS AGE to keep it consisten with the rest of columns
    ('name_updater', FeatureNameUpdater('BUSINESS AGE', 'BUSINESS_AGE')),
    
    # we impute missing values with mode or according to distribution (in case when missing value is mode)
    ('imputer', MyImputer(['AREA', 'EDUCATION'], ['ECONOMIC_SECTOR', 'EMPLOYEE_NO'])),
    
    # encoding columns (those in a list) with one-hot encoding as they have no order
    # EMPLOYEE_NO is encoded using OrdinalEncoder with specified order of values
    ('encoder', MyEncoder(["PRODUCT", "AREA", "RESIDENTIAL_PLACE", "EDUCATION", "MARITAL_STATUS",
                           "ECONOMIC_SECTOR"], 'EMPLOYEE_NO', ["between 0-10", "between 11-20",
                                                               "between 21-50", "between 51-100",
                                                               "between 101-250", "between 251-500",
                                                               "between 501-1.000", "> 1.000"])),
    
    # Replace outliers in chosen columns, you can also provide parameter k for the iqr scaling (1.5 default)
    ('outlier_replacer', OutlierReplacer(['LENGTH_RELATIONSHIP_WITH_CLIENT', 'WORK_SENIORITY', 'BUSINESS_AGE', 'INCOME'])),
    
    # scaling numerical data, you can choose whether to standarize(True) or minmax(False) (TODO: fix scaling 0-1 type features)
    ('scaler', MyScaler(standarize=False))
])

X_train_transformed = pipeline_processing.fit_transform(X_train)

# %% [markdown]
# From our EDA we remember that some categorical columns had values that appeared very rarely, hence some of the columns after encoding might have near zero variance and should be removed.

# %%
from tabulate import tabulate

encoded_columns = X_train_transformed.select_dtypes(include=['bool'])

# dictionary for saving number of true values in particular columns
dict_true_values = {}

for col_name in encoded_columns.columns:
    # calculate number of true values and add to dict
    number_of_true_values = encoded_columns[col_name].sum()
    dict_true_values[col_name] = number_of_true_values

# sort keys by values
keys_sorted = sorted(dict_true_values, key=dict_true_values.get)

data = [(key, dict_true_values[key], len(X_train_transformed), (dict_true_values[key] * 100) / len(X_train_transformed)) for key in keys_sorted]

print(tabulate(data, headers=['Column', 'True values', 'Total', 'Percentage'], tablefmt='simple'))
# Out:
# Column                                                               True values    Total    Percentage
# -----------------------------------------------------------------  -------------  -------  ------------
# PRODUCT_D                                                                     13    15097     0.0861098
# RESIDENTIAL_PLACE_Rental                                                      28    15097     0.185467
# EDUCATION_Primary school                                                      28    15097     0.185467
# PRODUCT_A                                                                     42    15097     0.278201
# ECONOMIC_SECTOR_Real estate activities                                        79    15097     0.523283
# ECONOMIC_SECTOR_Electricity and gas                                          152    15097     1.00682
# ECONOMIC_SECTOR_Accommodation and food service activities                    159    15097     1.05319
# EDUCATION_Middle school                                                      195    15097     1.29165
# ECONOMIC_SECTOR_Agriculture, hunting and forestry                            196    15097     1.29827
# ECONOMIC_SECTOR_Mining and quarrying                                         205    15097     1.35789
# RESIDENTIAL_PLACE_Other                                                      246    15097     1.62946
# ECONOMIC_SECTOR_Financial and insurance activities                           274    15097     1.81493
# ECONOMIC_SECTOR_Water supply                                                 333    15097     2.20574
# ECONOMIC_SECTOR_Construction                                                 358    15097     2.37133
# ECONOMIC_SECTOR_Professional, scientific and technical activities            393    15097     2.60317
# ECONOMIC_SECTOR_Education                                                    460    15097     3.04696
# ECONOMIC_SECTOR_Information and communication                                517    15097     3.42452
# EDUCATION_College                                                            562    15097     3.72259
# ECONOMIC_SECTOR_Human health and social work activities                      668    15097     4.42472
# ECONOMIC_SECTOR_Transportation and storage                                   691    15097     4.57707
# MARITAL_STATUS_widow                                                         798    15097     5.28582
# EDUCATION_Other                                                              819    15097     5.42492
# ECONOMIC_SECTOR_Other                                                        840    15097     5.56402
# RESIDENTIAL_PLACE_Owner with mortgage                                        861    15097     5.70312
# MARITAL_STATUS_divorced                                                     1045    15097     6.92191
# EDUCATION_Post-graduate                                                     1046    15097     6.92853
# EDUCATION_Vocational school                                                 1228    15097     8.13407
# ECONOMIC_SECTOR_Public administration and defence                           1257    15097     8.32616
# ECONOMIC_SECTOR_Wholesale and retail trade                                  1413    15097     9.35948
# PRODUCT_E                                                                   1522    15097    10.0815
# EDUCATION_Post secondary school                                             1620    15097    10.7306
# AREA_Urban area                                                             3286    15097    21.7659
# PRODUCT_F                                                                   3334    15097    22.0839
# PRODUCT_B                                                                   3407    15097    22.5674
# EDUCATION_Highschool                                                        3451    15097    22.8588
# AREA_Rural area                                                             4192    15097    27.7671
# MARITAL_STATUS_single                                                       5113    15097    33.8677
# RESIDENTIAL_PLACE_Living with family                                        5505    15097    36.4642
# EDUCATION_University                                                        6148    15097    40.7233
# PRODUCT_C                                                                   6779    15097    44.903
# ECONOMIC_SECTOR_Manufacturing                                               7102    15097    47.0425
# AREA_County capital                                                         7619    15097    50.467
# MARITAL_STATUS_married                                                      8141    15097    53.9246
# RESIDENTIAL_PLACE_Owner without mortgage                                    8457    15097    56.0178

# %% [markdown]
# We can safely delete PRODUCT_D, RESIDENTIAL_PLACE_Rental, EDUCATION_Primary School and PRODUCT_A
# (not sure were to set the threshold for removal)

# %%
columns_to_drop = ['PRODUCT_D', 'RESIDENTIAL_PLACE_Rental', 'EDUCATION_Primary school', 'PRODUCT_A']
X_train_transformed = X_train_transformed.drop(columns_to_drop, axis=1)

# although we already removed columns we will add this step to pipeline
# so that whole data processing is saved in it
pipeline_processing.steps.append(['encoded_feature_remover', FeatureRemover(columns_to_drop=columns_to_drop)])

# %%
import joblib

joblib.dump(pipeline_processing, 'processing_pipeline.joblib')
# Out:
# ['processing_pipeline.joblib']

# %% [markdown]
# ## Highly correlated features

# %% [markdown]
# From EDA heat map we know that there were some highly correlated features, let's display them now.

# %%
from tabulate import tabulate

def find_correlated_pairs(X, k):
    # Calculate Pearson correlation coefficients
    pearson_corr = X.corr(method='pearson')

    # Calculate Spearman correlation coefficients
    spearman_corr = X.corr(method='spearman')

    # Initialize lists to store correlated pairs
    pearson_correlated_pairs = []
    spearman_correlated_pairs = []
    
    # Initialize set for storing column names
    cols = set()

    # Loop through each pair of features
    for i in range(len(X.columns)):
        for j in range(len(X.columns)):
            if i > j:
                # Check Pearson correlation coefficient
                if abs(pearson_corr.iloc[i, j]) > k:
                    col1, col2 = pearson_corr.columns[i], pearson_corr.columns[j]
                    pearson_correlated_pairs.append((col1, col2, round(pearson_corr.loc[col1, col2], 2)))
                    cols.add(col1)
                    cols.add(col2)
                # Check Spearman correlation coefficient
                if abs(spearman_corr.iloc[i, j]) > k:
                    col1, col2 = spearman_corr.columns[i], pearson_corr.columns[j]
                    spearman_correlated_pairs.append((col1, col2, round(spearman_corr.loc[col1, col2], 2)))
                    cols.add(col1)
                    cols.add(col2)

    return pearson_correlated_pairs, spearman_correlated_pairs, cols


pearson_pairs, spearman_pairs, cols = find_correlated_pairs(X_train_transformed, 0.7)

# tuples to lists
pearson_pairs_data = [[pair[0], pair[1], pair[2]] for pair in pearson_pairs]
spearman_pairs_data = [[pair[0], pair[1], pair[2]] for pair in spearman_pairs]

print("Pearson Correlated Pairs:")
print(tabulate(pearson_pairs_data, headers=["Column 1", "Column 2", "Correlation"], tablefmt="simple"))
print("\nSpearman Correlated Pairs:")
print(tabulate(spearman_pairs_data, headers=["Column 1", "Column 2", "Correlation"], tablefmt="simple"))
# Out:
# Pearson Correlated Pairs:
# Column 1                                  Column 2                                Correlation
# ----------------------------------------  ------------------------------------  -------------
# NO_OF_DEPENDENTS                          HOUSEHOLD_MEMBERS                              0.73
# CURRENT_ACCOUNT                           DEBIT_CARD                                     0.81
# RESIDENTIAL_PLACE_Owner without mortgage  RESIDENTIAL_PLACE_Living with family          -0.85
# MARITAL_STATUS_married                    HOUSEHOLD_MEMBERS                              0.78
# MARITAL_STATUS_single                     MARITAL_STATUS_married                        -0.77
#
# Spearman Correlated Pairs:
# Column 1                                  Column 2                                Correlation
# ----------------------------------------  ------------------------------------  -------------
# CURRENT_ACCOUNT                           DEBIT_CARD                                     0.81
# RESIDENTIAL_PLACE_Owner without mortgage  RESIDENTIAL_PLACE_Living with family          -0.85
# MARITAL_STATUS_married                    HOUSEHOLD_MEMBERS                              0.88
# MARITAL_STATUS_single                     HOUSEHOLD_MEMBERS                             -0.71
# MARITAL_STATUS_single                     MARITAL_STATUS_married                        -0.77

# %% [markdown]
# ## Lets check correlation of these features with target

# %%
def get_sorted_correlations(X, cols, target):
    # Calculate correlations with target for each column in cols
    correlations = {}
    for col in cols:
        correlation = target.corr(X[col])
        correlations[col] = round(correlation, 2)

    # Sort correlations in descending order
    sorted_correlations = sorted(correlations.items(), key=lambda x: abs(x[1]), reverse=True)
    
    return sorted_correlations

sorted_correlations = get_sorted_correlations(X_train_transformed, cols, target)

print(tabulate(sorted_correlations, headers=["Column", "Correlation with Target"], tablefmt="simple"))
# Out:
# Column                                      Correlation with Target
# ----------------------------------------  -------------------------
# MARITAL_STATUS_single                                          0.16
# MARITAL_STATUS_married                                        -0.14
# RESIDENTIAL_PLACE_Living with family                           0.12
# HOUSEHOLD_MEMBERS                                             -0.1
# RESIDENTIAL_PLACE_Owner without mortgage                      -0.09
# CURRENT_ACCOUNT                                               -0.03
# DEBIT_CARD                                                    -0.02
# NO_OF_DEPENDENTS                                               0.01

# %% [markdown]
# ## Also lets see feature importance in RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train_transformed, target)

# Get feature importances from the classifier
feature_importances = rf_classifier.feature_importances_

# Create a DataFrame and sort by importance
importance_df = pd.DataFrame({'Feature': X_train_transformed.columns, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

print(tabulate(importance_df, headers='keys', tablefmt='simple', showindex=False))
# Out:
# Feature                                                              Importance
# -----------------------------------------------------------------  ------------
# INCOME                                                              0.154286
# AGE                                                                 0.136835
# BUSINESS_AGE                                                        0.0900099
# WORK_SENIORITY                                                      0.0691047
# EMPLOYEE_NO                                                         0.056043
# LENGTH_RELATIONSHIP_WITH_CLIENT                                     0.05488
# CURRENT_ACCOUNT                                                     0.0185872
# NO_OF_DEPENDENTS                                                    0.0180396
# EDUCATION_University                                                0.0177675
# AREA_County capital                                                 0.0176892
# AREA_Rural area                                                     0.0173896
# ECONOMIC_SECTOR_Manufacturing                                       0.0173183
# PRODUCT_F                                                           0.0168814
# HOUSEHOLD_MEMBERS                                                   0.0166355
# EDUCATION_Highschool                                                0.016476
# AREA_Urban area                                                     0.0163058
# MARITAL_STATUS_single                                               0.0162844
# RESIDENTIAL_PLACE_Living with family                                0.0152279
# DEBIT_CARD                                                          0.0151147
# EDUCATION_Post secondary school                                     0.0148324
# PRODUCT_C                                                           0.0144275
# ECONOMIC_SECTOR_Wholesale and retail trade                          0.013911
# EDUCATION_Other                                                     0.0136866
# PRODUCT_B                                                           0.0135098
# RESIDENTIAL_PLACE_Owner without mortgage                            0.0126089
# MARITAL_STATUS_married                                              0.0108289
# EDUCATION_Vocational school                                         0.00982229
# SALARY_ACCOUNT                                                      0.00964306
# EDUCATION_College                                                   0.00950216
# ECONOMIC_SECTOR_Transportation and storage                          0.00855022
# ECONOMIC_SECTOR_Other                                               0.00826577
# EDUCATION_Middle school                                             0.00757423
# ECONOMIC_SECTOR_Public administration and defence                   0.00609876
# ECONOMIC_SECTOR_Accommodation and food service activities           0.00598666
# ECONOMIC_SECTOR_Human health and social work activities             0.00587551
# ECONOMIC_SECTOR_Water supply                                        0.00584651
# MARITAL_STATUS_divorced                                             0.00582803
# PRODUCT_E                                                           0.00575714
# EDUCATION_Post-graduate                                             0.00547604
# ECONOMIC_SECTOR_Agriculture, hunting and forestry                   0.00544011
# ECONOMIC_SECTOR_Construction                                        0.00524568
# RESIDENTIAL_PLACE_Other                                             0.00456012
# MARITAL_STATUS_widow                                                0.00394277
# ECONOMIC_SECTOR_Professional, scientific and technical activities   0.00258204
# ECONOMIC_SECTOR_Education                                           0.00210646
# ECONOMIC_SECTOR_Information and communication                       0.00200596
# ECONOMIC_SECTOR_Real estate activities                              0.00151519
# RESIDENTIAL_PLACE_Owner with mortgage                               0.00148764
# ECONOMIC_SECTOR_Financial and insurance activities                  0.00105485
# ECONOMIC_SECTOR_Electricity and gas                                 0.000813734
# ECONOMIC_SECTOR_Mining and quarrying                                0.00033821

# %% [markdown]
# ## Summarize these outcomes

# %% [markdown]
# This summarization below contains no new data, it was just created for pracitcal reason to avoid scrolling through cells.

# %%
def create_table(X, triple, feature_importances):
    # Extract elements from the triple
    col1, col2, correlation = triple

    # Get correlation with target for each column
    corr_with_target_col1 = round(target.corr(X[col1]), 2)
    corr_with_target_col2 = round(target.corr(X[col2]), 2)

    # Get feature importances for each column
    importance_col1 = feature_importances.loc[feature_importances['Feature'] == col1, 'Importance'].values[0]
    importance_col2 = feature_importances.loc[feature_importances['Feature'] == col2, 'Importance'].values[0]

    # Construct the table as a DataFrame
    table = pd.DataFrame({
        '': ['Correlation with target', 'Feature importance'],
        col1: [corr_with_target_col1, importance_col1],
        col2: [corr_with_target_col2, importance_col2]
    })

    return table


print('---Pearson Correlation---\n')
for pair in pearson_pairs:
    print(pair)
    table = create_table(X_train_transformed, pair, importance_df)
    print(table, '\n')

# There is only one pair that appeared in Spearman correlation pairs and not in Pearson pair
# We will display only this pair not to print redundant data

print('---Spearman Correlation---\n')
print(spearman_pairs[3])
print(create_table(X_train_transformed, spearman_pairs[3], importance_df))
# Out:
# ---Pearson Correlation---
#
# ('NO_OF_DEPENDENTS', 'HOUSEHOLD_MEMBERS', 0.73)
#                             NO_OF_DEPENDENTS  HOUSEHOLD_MEMBERS
# 0  Correlation with target           0.01000          -0.100000
# 1       Feature importance           0.01804           0.016635
#
# ('CURRENT_ACCOUNT', 'DEBIT_CARD', 0.81)
#                             CURRENT_ACCOUNT  DEBIT_CARD
# 0  Correlation with target        -0.030000   -0.020000
# 1       Feature importance         0.018587    0.015115
#
# ('RESIDENTIAL_PLACE_Owner without mortgage', 'RESIDENTIAL_PLACE_Living with family', -0.85)
#                             RESIDENTIAL_PLACE_Owner without mortgage  \
# 0  Correlation with target                                 -0.090000
# 1       Feature importance                                  0.012609
#
#    RESIDENTIAL_PLACE_Living with family
# 0                              0.120000
# 1                              0.015228
#
# ('MARITAL_STATUS_married', 'HOUSEHOLD_MEMBERS', 0.78)
#                             MARITAL_STATUS_married  HOUSEHOLD_MEMBERS
# 0  Correlation with target               -0.140000          -0.100000
# 1       Feature importance                0.010829           0.016635
#
# ('MARITAL_STATUS_single', 'MARITAL_STATUS_married', -0.77)
#                             MARITAL_STATUS_single  MARITAL_STATUS_married
# 0  Correlation with target               0.160000               -0.140000
# 1       Feature importance               0.016284                0.010829
#
# ---Spearman Correlation---
#
# ('MARITAL_STATUS_single', 'HOUSEHOLD_MEMBERS', -0.71)
#                             MARITAL_STATUS_single  HOUSEHOLD_MEMBERS
# 0  Correlation with target               0.160000          -0.100000
# 1       Feature importance               0.016284           0.016635

# %% [markdown]
# From the above data we belive that it will be beneficial for the model if we delete features: DEBIT_CARD and NO_OF_DEPENDENTS as they are highly correlated with CURRENT_ACCOUNT and HOUSEHOLD_MEMBERS respectively and have low correlation with target. Although they both have slightly greater importance according to RFC we believe that differences in correlation with target is more significant.
#
# We will not delete any other features from above pair even though they are highly correlated with each other, because they have high correlation with target and from our EDA we know that we do not have many features with high correlation with target, hence they are valuable for us.

# %%
X_train_transformed = X_train_transformed.drop(['DEBIT_CARD', 'NO_OF_DEPENDENTS'], axis=1)

# %% [markdown]
# ### GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_classifier = GradientBoostingClassifier()
gb_classifier.fit(X_train_transformed, target)

# Get feature importances from the classifier
feature_importances_gb = gb_classifier.feature_importances_

# Create a DataFrame and sort by importance
importance_df_gb = pd.DataFrame({'Feature': X_train_transformed.columns, 'Importance': feature_importances_gb})
importance_df_gb = importance_df_gb.sort_values(by='Importance', ascending=False)

print(tabulate(importance_df_gb, headers='keys', tablefmt='simple', showindex=False))
# Out:
# Feature                                                              Importance
# -----------------------------------------------------------------  ------------
# AGE                                                                 0.181786
# INCOME                                                              0.171761
# PRODUCT_F                                                           0.12132
# WORK_SENIORITY                                                      0.0979515
# RESIDENTIAL_PLACE_Living with family                                0.0816469
# MARITAL_STATUS_single                                               0.0633079
# LENGTH_RELATIONSHIP_WITH_CLIENT                                     0.0306352
# BUSINESS_AGE                                                        0.0259598
# NO_OF_DEPENDENTS                                                    0.0249576
# CURRENT_ACCOUNT                                                     0.0246998
# MARITAL_STATUS_married                                              0.0221815
# EMPLOYEE_NO                                                         0.0212199
# EDUCATION_Other                                                     0.0146592
# EDUCATION_Middle school                                             0.0120773
# EDUCATION_Post secondary school                                     0.00843494
# RESIDENTIAL_PLACE_Other                                             0.00790409
# DEBIT_CARD                                                          0.00750502
# EDUCATION_Highschool                                                0.0070959
# ECONOMIC_SECTOR_Accommodation and food service activities           0.00680727
# ECONOMIC_SECTOR_Wholesale and retail trade                          0.00643493
# ECONOMIC_SECTOR_Agriculture, hunting and forestry                   0.00600445
# AREA_Rural area                                                     0.00552339
# HOUSEHOLD_MEMBERS                                                   0.00486998
# ECONOMIC_SECTOR_Other                                               0.00417284
# EDUCATION_Primary school                                            0.00406804
# ECONOMIC_SECTOR_Information and communication                       0.00390103
# SALARY_ACCOUNT                                                      0.00325726
# ECONOMIC_SECTOR_Manufacturing                                       0.00289488
# EDUCATION_College                                                   0.00249415
# EDUCATION_Post-graduate                                             0.0024719
# PRODUCT_B                                                           0.00232743
# ECONOMIC_SECTOR_Professional, scientific and technical activities   0.00212841
# ECONOMIC_SECTOR_Construction                                        0.00199185
# ECONOMIC_SECTOR_Water supply                                        0.00187447
# MARITAL_STATUS_divorced                                             0.00181841
# AREA_Urban area                                                     0.00148294
# ECONOMIC_SECTOR_Public administration and defence                   0.00145398
# ECONOMIC_SECTOR_Human health and social work activities             0.00140273
# PRODUCT_C                                                           0.00132272
# ECONOMIC_SECTOR_Education                                           0.00123976
# RESIDENTIAL_PLACE_Owner with mortgage                               0.00120495
# AREA_County capital                                                 0.0011829
# ECONOMIC_SECTOR_Financial and insurance activities                  0.000790291
# RESIDENTIAL_PLACE_Owner without mortgage                            0.000600813
# ECONOMIC_SECTOR_Real estate activities                              0.000598291
# MARITAL_STATUS_widow                                                0.000202394
# PRODUCT_E                                                           0.000194813
# ECONOMIC_SECTOR_Transportation and storage                          0.000179817
# ECONOMIC_SECTOR_Mining and quarrying                                0
# EDUCATION_Vocational school                                         0
# ECONOMIC_SECTOR_Electricity and gas                                 0
# RESIDENTIAL_PLACE_Rental                                            0
# PRODUCT_A                                                           0
# EDUCATION_University                                                0
# PRODUCT_D                                                           0

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X_train_transformed, target)

# Get coefficients from the classifier
coefficients_svm = svm_classifier.coef_[0]

# Create a DataFrame and sort by coefficient magnitude
importance_df_svm = pd.DataFrame({'Feature': X_train_transformed.columns, 'Coefficient': coefficients_svm})
importance_df_svm['Importance'] = importance_df_svm['Coefficient'].abs()  # Absolute value of coefficients for importance
importance_df_svm = importance_df_svm.sort_values(by='Importance', ascending=False)

print(tabulate(importance_df_svm, headers='keys', tablefmt='simple', showindex=False))
# Out:
# Feature                                                              Coefficient    Importance
# -----------------------------------------------------------------  -------------  ------------
# HOUSEHOLD_MEMBERS                                                   -0.000719328   0.000719328
# NO_OF_DEPENDENTS                                                     0.000690818   0.000690818
# ECONOMIC_SECTOR_Electricity and gas                                 -0.000272233   0.000272233
# RESIDENTIAL_PLACE_Rental                                            -0.000253251   0.000253251
# EDUCATION_Primary school                                             0.0002465     0.0002465
# MARITAL_STATUS_married                                               0.000172975   0.000172975
# EDUCATION_Post-graduate                                             -0.000164117   0.000164117
# MARITAL_STATUS_widow                                                -0.000126276   0.000126276
# RESIDENTIAL_PLACE_Other                                              0.000125069   0.000125069
# ECONOMIC_SECTOR_Information and communication                       -0.000119288   0.000119288
# RESIDENTIAL_PLACE_Owner without mortgage                             0.000116314   0.000116314
# ECONOMIC_SECTOR_Accommodation and food service activities            0.000103214   0.000103214
# EDUCATION_College                                                   -9.66477e-05   9.66477e-05
# ECONOMIC_SECTOR_Financial and insurance activities                   8.67838e-05   8.67838e-05
# INCOME                                                               7.57715e-05   7.57715e-05
# EDUCATION_Other                                                     -7.52024e-05   7.52024e-05
# MARITAL_STATUS_single                                               -6.92389e-05   6.92389e-05
# ECONOMIC_SECTOR_Manufacturing                                        6.53088e-05   6.53088e-05
# ECONOMIC_SECTOR_Human health and social work activities              6.45746e-05   6.45746e-05
# CURRENT_ACCOUNT                                                      6.27536e-05   6.27536e-05
# PRODUCT_F                                                           -5.64553e-05   5.64553e-05
# ECONOMIC_SECTOR_Professional, scientific and technical activities   -5.60112e-05   5.60112e-05
# ECONOMIC_SECTOR_Transportation and storage                           5.1783e-05    5.1783e-05
# PRODUCT_C                                                            5.02722e-05   5.02722e-05
# ECONOMIC_SECTOR_Wholesale and retail trade                          -4.88983e-05   4.88983e-05
# LENGTH_RELATIONSHIP_WITH_CLIENT                                     -4.88896e-05   4.88896e-05
# BUSINESS_AGE                                                        -4.69691e-05   4.69691e-05
# EDUCATION_Highschool                                                 4.65506e-05   4.65506e-05
# ECONOMIC_SECTOR_Water supply                                         4.63319e-05   4.63319e-05
# EDUCATION_Middle school                                              4.49254e-05   4.49254e-05
# AREA_County capital                                                 -4.11006e-05   4.11006e-05
# ECONOMIC_SECTOR_Education                                            3.71979e-05   3.71979e-05
# DEBIT_CARD                                                           3.64447e-05   3.64447e-05
# AGE                                                                  3.04626e-05   3.04626e-05
# AREA_Urban area                                                      2.68569e-05   2.68569e-05
# PRODUCT_E                                                            2.62052e-05   2.62052e-05
# EDUCATION_University                                                -2.56822e-05   2.56822e-05
# ECONOMIC_SECTOR_Public administration and defence                    2.53169e-05   2.53169e-05
# MARITAL_STATUS_divorced                                              2.25398e-05   2.25398e-05
# ECONOMIC_SECTOR_Mining and quarrying                                -2.15678e-05   2.15678e-05
# EDUCATION_Vocational school                                          2.09716e-05   2.09716e-05
# PRODUCT_B                                                           -2.00221e-05   2.00221e-05
# ECONOMIC_SECTOR_Construction                                         1.70671e-05   1.70671e-05
# ECONOMIC_SECTOR_Agriculture, hunting and forestry                    1.56323e-05   1.56323e-05
# AREA_Rural area                                                      1.42436e-05   1.42436e-05
# EMPLOYEE_NO                                                         -1.10577e-05   1.10577e-05
# RESIDENTIAL_PLACE_Living with family                                 1.03565e-05   1.03565e-05
# WORK_SENIORITY                                                      -9.68827e-06   9.68827e-06
# SALARY_ACCOUNT                                                      -5.99848e-06   5.99848e-06
# ECONOMIC_SECTOR_Other                                                5.62563e-06   5.62563e-06
# EDUCATION_Post secondary school                                      2.70152e-06   2.70152e-06
# RESIDENTIAL_PLACE_Owner with mortgage                                1.51138e-06   1.51138e-06
# ECONOMIC_SECTOR_Real estate activities                              -8.37296e-07   8.37296e-07
# PRODUCT_D                                                            0             0
# PRODUCT_A                                                            0             0

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

logistic_regression = LogisticRegression()

logistic_regression.fit(X_train_transformed, target)

coefficients_logistic_regression = logistic_regression.coef_[0]

importance_df_logistic_regression = pd.DataFrame({'Feature': X_train_transformed.columns, 'Coefficient': coefficients_logistic_regression})
importance_df_logistic_regression['Importance'] = importance_df_logistic_regression['Coefficient'].abs()
importance_df_logistic_regression = importance_df_logistic_regression.sort_values(by='Importance', ascending=False)

print(tabulate(importance_df_logistic_regression, headers='keys', tablefmt='simple', showindex=False))
# Out:
# Feature                                                              Coefficient    Importance
# -----------------------------------------------------------------  -------------  ------------
# PRODUCT_F                                                             -2.24656       2.24656
# WORK_SENIORITY                                                        -1.47023       1.47023
# NO_OF_DEPENDENTS                                                       1.30574       1.30574
# RESIDENTIAL_PLACE_Owner with mortgage                                 -1.23789       1.23789
# LENGTH_RELATIONSHIP_WITH_CLIENT                                       -1.05836       1.05836
# ECONOMIC_SECTOR_Financial and insurance activities                    -1.02765       1.02765
# PRODUCT_B                                                              0.97702       0.97702
# ECONOMIC_SECTOR_Information and communication                         -0.975937      0.975937
# PRODUCT_C                                                              0.839973      0.839973
# ECONOMIC_SECTOR_Mining and quarrying                                  -0.826794      0.826794
# PRODUCT_E                                                              0.793806      0.793806
# RESIDENTIAL_PLACE_Other                                                0.786454      0.786454
# ECONOMIC_SECTOR_Accommodation and food service activities              0.770815      0.770815
# RESIDENTIAL_PLACE_Living with family                                   0.745033      0.745033
# EDUCATION_Post-graduate                                               -0.722767      0.722767
# EDUCATION_Primary school                                               0.714794      0.714794
# ECONOMIC_SECTOR_Agriculture, hunting and forestry                      0.691976      0.691976
# INCOME                                                                -0.67192       0.67192
# EDUCATION_Middle school                                                0.639752      0.639752
# HOUSEHOLD_MEMBERS                                                     -0.626126      0.626126
# ECONOMIC_SECTOR_Education                                             -0.606672      0.606672
# ECONOMIC_SECTOR_Electricity and gas                                   -0.568825      0.568825
# ECONOMIC_SECTOR_Wholesale and retail trade                             0.533461      0.533461
# AGE                                                                   -0.453392      0.453392
# ECONOMIC_SECTOR_Water supply                                           0.444059      0.444059
# ECONOMIC_SECTOR_Construction                                           0.434698      0.434698
# ECONOMIC_SECTOR_Human health and social work activities                0.429345      0.429345
# RESIDENTIAL_PLACE_Rental                                              -0.428182      0.428182
# ECONOMIC_SECTOR_Transportation and storage                             0.421661      0.421661
# MARITAL_STATUS_single                                                  0.412142      0.412142
# CURRENT_ACCOUNT                                                       -0.365737      0.365737
# MARITAL_STATUS_married                                                -0.360641      0.360641
# ECONOMIC_SECTOR_Manufacturing                                          0.349731      0.349731
# EDUCATION_Highschool                                                  -0.345686      0.345686
# EDUCATION_Other                                                        0.334688      0.334688
# EDUCATION_Vocational school                                           -0.302164      0.302164
# PRODUCT_A                                                             -0.228617      0.228617
# MARITAL_STATUS_widow                                                  -0.218969      0.218969
# EDUCATION_University                                                  -0.213236      0.213236
# ECONOMIC_SECTOR_Real estate activities                                 0.169008      0.169008
# PRODUCT_D                                                             -0.156498      0.156498
# MARITAL_STATUS_divorced                                                0.146589      0.146589
# SALARY_ACCOUNT                                                         0.137533      0.137533
# BUSINESS_AGE                                                          -0.123821      0.123821
# ECONOMIC_SECTOR_Professional, scientific and technical activities     -0.123407      0.123407
# RESIDENTIAL_PLACE_Owner without mortgage                               0.113704      0.113704
# AREA_County capital                                                   -0.110737      0.110737
# EDUCATION_College                                                     -0.105013      0.105013
# ECONOMIC_SECTOR_Other                                                 -0.0737474     0.0737474
# ECONOMIC_SECTOR_Public administration and defence                     -0.0626007     0.0626007
# AREA_Rural area                                                        0.0600753     0.0600753
# DEBIT_CARD                                                            -0.0461353     0.0461353
# AREA_Urban area                                                        0.0297831     0.0297831
# EMPLOYEE_NO                                                            0.025985      0.025985
# EDUCATION_Post secondary school                                       -0.0212483     0.0212483
# /Users/julia/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
